# %%
# !git clone https://github.com/faridahhani/practise_regression.git
# Out:
# Cloning into 'practise_regression'...
# ...

# %%
# %cd /content/practise_regression
# Out:
# /content/practise_regression

# %%
# Cell 3
from google.colab import drive
drive.mount('/content/drive')
